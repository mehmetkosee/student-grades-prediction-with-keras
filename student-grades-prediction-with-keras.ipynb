# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/student-grades-intermediate-dataset/Student_Grades.csv

# %%
import pandas as pd

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# 2025-07-16 20:20:27.673031: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752697227.942584      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752697228.022472      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
df = pd.read_csv('/kaggle/input/student-grades-intermediate-dataset/Student_Grades.csv')
df.head(5)
# Out:
#    Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 0    2.5       0.5       0.0        2        2.3      21     C
# 1    5.1       1.5       0.5        4        4.9      47     B
# 2    3.2       1.0       0.5        3        2.9      27     C
# 3    8.5       3.7       1.2        7        7.7      75     A
# 4    3.5       1.2       0.3        3        3.2      30     C

# %%
y = df['Scores']
x = df.drop(columns = ['Scores','Grade'])

y = y.values.astype('float32')
x = x.values.astype('float32')

# %%
model = Sequential()

model.add(Dense(16))
model.add(Dense(32 , activation = "relu"))
model.add(Dense(32 , activation = "relu"))
model.add(Dense(1))

model.compile(optimizer = "adam" , loss = "mse")

model.fit(x, y, epochs=128, batch_size=16)
# Out:
# Epoch 1/128
# 2025-07-16 20:20:45.287814: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3351.9927
# Epoch 2/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3422.3892
# Epoch 3/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3251.0491
# Epoch 4/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3060.3831
# Epoch 5/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3200.8591
# Epoch 6/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3262.9678
# Epoch 7/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2983.1072
# Epoch 8/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2914.9873
# Epoch 9/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2785.8884
# Epoch 10/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2900.8201
# Epoch 11/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2738.1514
# Epoch 12/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2767.2476
# Epoch 13/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2857.0085
# Epoch 14/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2565.5674
# Epoch 15/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2528.4712
# Epoch 16/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2491.3708
# Epoch 17/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2356.9387
# Epoch 18/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2285.7622
# Epoch 19/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2177.6125
# Epoch 20/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2209.4243
# Epoch 21/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2120.9673
# Epoch 22/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1940.5116
# Epoch 23/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1751.6515
# Epoch 24/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1680.6396
# Epoch 25/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1566.3977
# Epoch 26/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1408.6001
# Epoch 27/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1346.3087
# Epoch 28/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1302.6622
# Epoch 29/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1098.3043
# Epoch 30/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 980.5045
# Epoch 31/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 878.7231
# Epoch 32/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 789.3232
# Epoch 33/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 683.6536
# Epoch 34/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 538.5552
# Epoch 35/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 404.6250
# Epoch 36/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 346.0374
# Epoch 37/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 262.0606
# Epoch 38/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 204.1830
# Epoch 39/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 135.2715
# Epoch 40/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 81.7924
# Epoch 41/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 43.2660
# Epoch 42/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 24.1200
# Epoch 43/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 12.4960
# Epoch 44/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.2676
# Epoch 45/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.1751
# Epoch 46/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 11.6489
# Epoch 47/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 16.6711
# Epoch 48/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 21.4080
# Epoch 49/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 23.7795
# Epoch 50/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 22.3149
# Epoch 51/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 20.3738
# Epoch 52/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 20.2469
# Epoch 53/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 13.8221
# Epoch 54/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 12.2375
# Epoch 55/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 10.7695
# Epoch 56/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.3239
# Epoch 57/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.9489
# Epoch 58/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.1837
# Epoch 59/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.3778
# Epoch 60/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.1282
# Epoch 61/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.5852
# Epoch 62/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.2841
# Epoch 63/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.5607
# Epoch 64/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.2502
# Epoch 65/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.9875
# Epoch 66/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.6478
# Epoch 67/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.7348
# Epoch 68/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.7281
# Epoch 69/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.0354
# Epoch 70/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.3572
# Epoch 71/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.2444
# Epoch 72/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.9913
# Epoch 73/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.5026
# Epoch 74/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.5009
# Epoch 75/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.5053
# Epoch 76/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.0369
# Epoch 77/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.9043
# Epoch 78/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.7607
# Epoch 79/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.8109
# Epoch 80/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.4202
# Epoch 81/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.2001
# Epoch 82/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.7156
# Epoch 83/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.6840
# Epoch 84/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.6373
# Epoch 85/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.2648
# Epoch 86/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.5190
# Epoch 87/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.4325
# Epoch 88/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.5731
# Epoch 89/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.7364
# Epoch 90/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.8253
# Epoch 91/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.5944
# Epoch 92/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.1848
# Epoch 93/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.2216
# Epoch 94/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.2490
# Epoch 95/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.6343
# Epoch 96/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.3832
# Epoch 97/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.4853
# Epoch 98/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.2466
# Epoch 99/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.4858
# Epoch 100/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.7592
# Epoch 101/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.2486
# Epoch 102/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.1047
# Epoch 103/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.1042
# Epoch 104/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.1663
# Epoch 105/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.9356
# Epoch 106/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.7475
# Epoch 107/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.9244
# Epoch 108/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.8374
# Epoch 109/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.7115
# Epoch 110/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.9431
# Epoch 111/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.4105
# Epoch 112/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.4718
# Epoch 113/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.4546
# Epoch 114/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.4960
# Epoch 115/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.0570
# Epoch 116/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.6438
# Epoch 117/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.1235
# Epoch 118/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.8969
# Epoch 119/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.6700
# Epoch 120/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.0739
# Epoch 121/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.4396
# Epoch 122/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.1112
# Epoch 123/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.3200
# Epoch 124/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.0798
# Epoch 125/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.6465
# Epoch 126/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.6187
# Epoch 127/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.0149
# Epoch 128/128
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.9589

# %%
df.head(3)
# Out:
#    Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 0    2.5       0.5       0.0        2        2.3      21     C
# 1    5.1       1.5       0.5        4        4.9      47     B
# 2    3.2       1.0       0.5        3        2.9      27     C

# %%
model.predict(np.array([[5, 1, 0.5, 4, 4.2,]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# array([[42.89322]], dtype=float32)
